# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from collections import Counter

def get_top_five_predictions(image_path):
    try:
        img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array = tf.keras.applications.resnet50.preprocess_input(img_array)
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        predictions = model.predict(img_array)
        decoded_predictions = tf.keras.applications.resnet50.decode_predictions(predictions, top=5)

        # Get the top five predictions for the image
        return decoded_predictions

    except Exception as e:
        print(f"Error processing image: {e}")
        return []
    
# Load pre-trained model (ResNet50)
model = tf.keras.applications.ResNet50(weights='imagenet', include_top=True)

# Input: Path to a single folder
main_folder = input("Enter the path to the main folder: ")

if not os.path.isdir(main_folder):
    print("Invalid folder path.")
    exit()
    
# Create a directed graph
G = nx.DiGraph()

# Add nodes for each category
categories = ["Siamese_cat", "tabby", "Persian_cat", "Egyptian_cat",
              "Chihuahua", "American_Staffordshire_terrier", "Boston_bull", "French_bulldog", "pug",
              "Angora", "hare", "wood_rabbit", "wallaby", "hamster", "beaver", "guinea_pig", "marmot",
              "American_coot", "drake", "goose", "black_swan", "red-breasted_merganser"]
for category in categories:
    G.add_node(category)

# Dictionary to store all the predictions for each folder
all_predictions = {}
    
# Dictionary to store all the flattened predictions for each folder
folder_flattened_predictions = {}

# Dictionary to store most common predictions for each folder
folder_most_common_predictions = {}

# Iterate through each category folder
for category_folder in os.listdir(main_folder):
    category_folder_path = os.path.join(main_folder, category_folder)

    if os.path.isdir(category_folder_path):
        print(f"Processing folder: {category_folder}")

        # Get all image files in the category folder
        image_files = [os.path.join(category_folder_path, file) for file in os.listdir(category_folder_path)]
        
        # Initialize predictions list for each category
        predictions = []

        # Call the function to get top five predictions
        for image_path in image_files:
            predictions.append(get_top_five_predictions(image_path))

        # Filter out None values (cases where there's only one unique prediction)
        predictions = [prediction for prediction in predictions if prediction is not None]
        print(predictions)
                
         # Flatten the predictions list
        flattened_predictions = [item[1] for per_image_prediction in predictions for prediction in per_image_prediction for item in prediction]

        # Find the most common prediction using Counter
        most_common_prediction = Counter(flattened_predictions).most_common(1)[0][0]
        
        # Store all the flattened prediction for each folder in the dictionary
        all_predictions[category_folder] = predictions

        # Store all the flattened prediction for each folder in the dictionary
        folder_flattened_predictions[category_folder] = flattened_predictions
        
        # Store the most common prediction for the folder in the dictionary
        folder_most_common_predictions[category_folder] = most_common_prediction
        
        print(f"Most common prediction for {category_folder}: {most_common_prediction}")

# Connect nodes based on hierarchy and calculate weights
for folder, prediction in folder_most_common_predictions.items():
    for other_folder, all_other_predictions in all_predictions.items():
        weight = 0
        for other_predictions in all_other_predictions:
            for other_prediction in other_predictions[0]:
                if folder != other_folder and prediction in other_prediction:
                    try:
                        if folder_most_common_predictions[folder] == other_prediction[1]:
                            weight += other_prediction[2]
                    except Exception as e:
                        print(f"Error processing prediction: {e}")
        print(folder_most_common_predictions[folder], folder_most_common_predictions[other_folder])
        print(weight)

        # Check if the edge already exists
        if weight != 0:
            if G.has_edge(folder_most_common_predictions[folder], folder_most_common_predictions[other_folder]):
                G[folder_most_common_predictions[folder]][folder_most_common_predictions[other_folder]]["weight"] += weight
            else:
                G.add_edge(folder_most_common_predictions[folder], folder_most_common_predictions[other_folder], weight=weight)

# Extract the weights of edges
weights = [d['weight'] for u, v, d in G.edges(data=True)]

# Divide the weights into groups
sorted_weights = sorted(weights)
group_size = len(weights) // 10
remainder = len(weights) % 10
groups = []
start_index = 0

for i in range(10):
    group_length = group_size + (1 if i < remainder else 0)
    groups.append(sorted_weights[start_index:start_index + group_length])
    start_index += group_length
    
# Create a copy of the graph to manipulate
G_copy = G.copy()
percentages = 100

# Visualize the tree
pos = nx.spring_layout(G_copy, seed=42, k=5, scale=3.0)
nx.draw(G_copy, pos, with_labels=True, node_color='skyblue', node_size=1500, font_size=10, font_color='black',
        font_weight='bold', edge_color='gray')

# Annotate edges with weights
for edge in G_copy.edges(data=True):
    weight = round(edge[2]["weight"], 2) # Round to two decimal places
    plt.annotate(str(weight), xy=(pos[edge[0]] + pos[edge[1]]) / 2, color='red', ha='center', va='center')

plt.title(f"Hierarchy graph (Weight Threshold: {percentages}%)")
plt.show()
    
for group in groups:
    # Define the maximum weight based on the percentage
    percentages -= 10
    
    if percentages >= 10:
        # Remove edges with weights below the threshold
        edges_to_remove = [(u, v) for u, v, d in G_copy.edges(data=True) if d['weight'] in group]
        G_copy.remove_edges_from(edges_to_remove)

        # Visualize the tree
        pos = nx.spring_layout(G_copy, seed=42, k=5, scale=3.0)
        nx.draw(G_copy, pos, with_labels=True, node_color='skyblue', node_size=1500, font_size=10, font_color='black',
                font_weight='bold', edge_color='gray')

        # Annotate edges with weights
        for edge in G_copy.edges(data=True):
            weight = round(edge[2]["weight"], 2) # Round to two decimal places
            plt.annotate(str(weight), xy=(pos[edge[0]] + pos[edge[1]]) / 2, color='red', ha='center', va='center')

        plt.title(f"Hierarchy graph (Weight Threshold: {percentages}%)")
        plt.show()
        
        # Print the strong connected components
        components = list(nx.strongly_connected_components(G_copy))
        print("\nComponents:")
        for i, component in enumerate(components, 1):
            print(f"Component {i}: {component}")
# Out:
# Enter the path to the main folder: C:\Users\osnat\Desktop\Shenkar\4th year\Final Project - XAI\Code\dogs and cats
# Processing folder: n01847000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 157ms/step
# [[[('n01847000', 'drake', 0.99986374), ('n02018207', 'American_coot', 9.239523e-05), ('n01855032', 'red-breasted_merganser', 1.7597078e-05), ('n01855672', 'goose', 1.6600865e-05), ('n02017213', 'European_gallinule', 6.0355524e-06)]], [[('n01847000', 'drake', 0.9804813), ('n01806143', 'peacock', 0.0099131735), ('n02018207', 'American_coot', 0.0076952917), ('n02017213', 'European_gallinule', 0.0010051575), ('n01855672', 'goose', 0.0002437351)]], [[('n01847000', 'drake', 0.99998844), ('n01855032', 'red-breasted_merganser', 5.9111644e-06), ('n01855672', 'goose', 4.8116217e-06), ('n01798484', 'prairie_chicken', 5.1645264e-07), ('n01806143', 'peacock', 2.457891e-07)]], [[('n01847000', 'drake', 0.9997029), ('n01806143', 'peacock', 0.00023099), ('n01833805', 'hummingbird', 3.917716e-05), ('n01855032', 'red-breasted_merganser', 1.2073773e-05), ('n02018207', 'American_coot', 1.7398382e-06)]], [[('n01847000', 'drake', 0.99991906), ('n02018207', 'American_coot', 6.604801e-05), ('n01855672', 'goose', 1.3489536e-05), ('n01855032', 'red-breasted_merganser', 8.097674e-07), ('n01860187', 'black_swan', 5.37446e-07)]], [[('n01847000', 'drake', 0.9989895), ('n01855672', 'goose', 0.00031109957), ('n02017213', 'European_gallinule', 8.7097185e-05), ('n01855032', 'red-breasted_merganser', 6.5904664e-05), ('n02058221', 'albatross', 5.0949522e-05)]], [[('n01847000', 'drake', 0.99989843), ('n01855032', 'red-breasted_merganser', 8.7839806e-05), ('n02018207', 'American_coot', 5.649682e-06), ('n01860187', 'black_swan', 3.5925707e-06), ('n02025239', 'ruddy_turnstone', 1.3476508e-06)]], [[('n01847000', 'drake', 0.61916476), ('n01855672', 'goose', 0.21548584), ('n01855032', 'red-breasted_merganser', 0.07185125), ('n01601694', 'water_ouzel', 0.023846092), ('n02033041', 'dowitcher', 0.023192042)]], [[('n01847000', 'drake', 0.9994592), ('n01855032', 'red-breasted_merganser', 0.00050697214), ('n02018207', 'American_coot', 1.0052468e-05), ('n01843065', 'jacamar', 5.3036115e-06), ('n02017213', 'European_gallinule', 3.5120013e-06)]], [[('n01847000', 'drake', 0.9999585), ('n01855032', 'red-breasted_merganser', 2.7420843e-05), ('n02018207', 'American_coot', 2.953472e-06), ('n02017213', 'European_gallinule', 1.9351212e-06), ('n02025239', 'ruddy_turnstone', 1.8425054e-06)]]]
# Most common prediction for n01847000: drake
# Processing folder: n01855032
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 203ms/step
# [[[('n01855032', 'red-breasted_merganser', 0.925078), ('n01855672', 'goose', 0.04053183), ('n02018207', 'American_coot', 0.026874142), ('n01847000', 'drake', 0.0032376468), ('n02002724', 'black_stork', 0.00069922674)]], [[('n01855032', 'red-breasted_merganser', 0.9665012), ('n02037110', 'oystercatcher', 0.029237902), ('n01847000', 'drake', 0.0026579516), ('n01855672', 'goose', 0.000744221), ('n02028035', 'redshank', 0.0003291914)]], [[('n01855032', 'red-breasted_merganser', 0.99893075), ('n02018207', 'American_coot', 0.00044496762), ('n01797886', 'ruffed_grouse', 0.00014406125), ('n01847000', 'drake', 0.0001091162), ('n02056570', 'king_penguin', 5.7451358e-05)]], [[('n01855032', 'red-breasted_merganser', 0.9998568), ('n02028035', 'redshank', 7.52858e-05), ('n01855672', 'goose', 1.7314413e-05), ('n01847000', 'drake', 1.5047357e-05), ('n02056570', 'king_penguin', 1.4226022e-05)]], [[('n01855032', 'red-breasted_merganser', 0.9774418), ('n02037110', 'oystercatcher', 0.009861288), ('n01847000', 'drake', 0.005400484), ('n02018207', 'American_coot', 0.0021882297), ('n01855672', 'goose', 0.0015650942)]], [[('n01855032', 'red-breasted_merganser', 0.9998228), ('n02018207', 'American_coot', 0.00011862538), ('n01855672', 'goose', 2.7273898e-05), ('n02071294', 'killer_whale', 1.7761735e-05), ('n01847000', 'drake', 8.97683e-06)]], [[('n01855032', 'red-breasted_merganser', 0.5954791), ('n02033041', 'dowitcher', 0.13782495), ('n02011460', 'bittern', 0.11991913), ('n02028
', 0.67320776), ('n02101556', 'clumber', 0.09702214), ('n02100735', 'English_setter', 0.033977002), ('n02100583', 'vizsla', 0.03335009), ('n02099849', 'Chesapeake_Bay_retriever', 0.023751073)]], [[('n02093256', 'Staffordshire_bullterrier', 0.97044367), ('n02093428', 'American_Staffordshire_terrier', 0.019337252), ('n02105412', 'kelpie', 0.0070915595), ('n02110958', 'pug', 0.0006774035), ('n02096585', 'Boston_bull', 0.0005114456)]], [[('n02093428', 'American_Staffordshire_terrier', 0.5071242), ('n02096585', 'Boston_bull', 0.25038046), ('n ...
# Most common prediction for n02093428-American_Staffordshire_terrier: American_Staffordshire_terrier
# Processing folder: n02096585-Boston_bull
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 188ms/step
# [[[('n02096585', 'Boston_bull', 0.99307466), ('n02108915', 'French_bulldog', 0.006795529), ('n02108089', 'boxer', 6.836825e-05), ('n02093428', 'American_Staffordshire_terrier', 3.1855743e-05), ('n02093256', 'Staffordshire_bullterrier', 2.579968e-05)]], [[('n02096585', 'Boston_bull', 0.9596258), ('n02108089', 'boxer', 0.03781047), ('n02108915', 'French_bulldog', 0.00094860815), ('n02109047', 'Great_Dane', 0.00046455231), ('n02109525', 'Saint_Bernard', 0.00019391146)]], [[('n02096585', 'Boston_bull', 0.8413944), ('n03218198', 'dogsled', 0.060979594), ('n02108089', 'boxer', 0.016348215), ('n02110958', 'pug', 0.01591359), ('n02087046', 'toy_terrier', 0.007774845)]], [[('n02096585', 'Boston_bull', 0.5267616), ('n02108915', 'French_bulldog', 0.3083987), ('n02087046', 'toy_terrier', 0.16360198), ('n02085620', 'Chihuahua', 0.0006508177), ('n02110806', 'basenji', 0.00019081998)]], [[('n02096585', 'Boston_bull', 0.8975569), ('n02108915', 'French_bulldog', 0.047745977), ('n02087046', 'toy_terrier', 0.024598159), ('n02085620', 'Chihuahua', 0.02446777), ('n02107312', 'miniature_pinscher', 0.0011123613)]], [[('n02096585', 'Boston_bull', 0.91261405), ('n02108915', 'French_bulldog', 0.056913458), ('n02087046', 'toy_terrier', 0.021376627), ('n02110806', 'basenji', 0.006476168), ('n02113186', 'Cardigan', 0.0006371428)]], [[('n02108915', 'French_bulldog', 0.9463373), ('n02096585', 'Boston_bull', 0.04647191), ('n02110806', 'basenji', 0.0010959757), ('n02087046', 'toy_terrier', 0.0010314442), ('n02093256', 'Staffordshire_bullterrier', 0.00076868344)]], [[('n02096585', 'Boston_bull', 0.9851409), ('n02108915', 'French_bulldog', 0.013658113), ('n02087046', 'toy_terrier', 0.00065780396), ('n02085620', 'Chihuahua', 7.9476755e-05), ('n04409515', 'tennis_ball', 3.3120028e-05)]], [[('n02096585', 'Boston_bull', 0.9518821), ('n02093256', 'Staffordshire_bullterrier', 0.02203349), ('n02093428', 'American_Staffordshire_terrier', 0.013598007), ('n02108915', 'French_bulldog', 0.011038752), ('n02110958', 'pug', 0.0003654582)]], [[('n02096585', 'Boston_bull', 0.9834282), ('n02110806', 'basenji', 0.007750085), ('n02087046', 'toy_terrier', 0.002144757), ('n02085620', 'Chihuahua', 0.0015
# French_bulldog Chihuahua
# 0.9712037479766877
# French_bulldog American_Staffordshire_terrier
# 0.3765206988582577
# French_bulldog Boston_bull
# 2.9373907392146066
# French_bulldog French_bulldog
# 0
# French_bulldog pug
# 0.42301394244032053
# French_bulldog tabby
# 0
# French_bulldog Persian_cat
# 0
# French_bulldog Siamese_cat
# 0
# French_bulldog Egyptian_cat
# 0
# French_bulldog wood_rabbit
# 0
# French_bulldog hare
# 0
# French_bulldog Angora
# 0
# French_bulldog hamster
# 0
# French_bulldog marmot
# 0
# French_bulldog beaver
# 0
# French_bulldog guinea_pig
# 0
# pug drake
# 0
# pug red-breasted_merganser
# 0
# pug goose
# 0
# pug black_swan
# 0
# pug wallaby
# 0
# pug American_coot
# 0
# pug Chihuahua
# 0
# pug American_Staffordshire_terrier
# 0.0013052568538114429
# pug Boston_bull
# 0.03502428734645946
# pug French_bulldog
# 0.5641119966885526
# pug pug
# 0
# pug tabby
# 0.067641481757164
# pug Persian_cat
# 0
# pug Siamese_cat
# 0.005503841945028398
# pug Egyptian_cat
# 0
# pug wood_rabbit
# 0
# pug hare
# 0
# pug Angora
# 0
# pug hamster
# 0
# pug marmot
# 0
# pug beaver
# 0
# pug guinea_pig
# 0
# tabby drake
# 0
# tabby red-breasted_merganser
# 0
# tabby goose
# 0
# tabby black_swan
# 0
# tabby wallaby
# 0
# tabby American_coot
# 0
# tabby Chihuahua
# 0
# tabby American_Staffordshire_terrier
# 0
# tabby Boston_bull
# 0
# tabby French_bulldog
# 0
# tabby pug
# 0
# tabby tabby
# 0
# tabby Persian_cat
# 0.0028071123703625744
# tabby Siamese_cat
# 0
# tabby Egyptian_cat
# 1.554147749200638
# tabby wood_rabbit
# 0
# tabby hare
# 0
# tabby Angora
# 0
# tabby hamster
# 0
# tabby marmot
# 0
# tabby beaver
# 0
# tabby guinea_pig
# 0
# Persian_cat drake
# 0
# Persian_cat red-breasted_merganser
# 0
# Persian_cat goose
# 0
# Persian_cat black_swan
# 0
# Persian_cat wallaby
# 0
# Persian_cat American_coot
# 0
# Persian_cat Chihuahua
# 0
# Persian_cat American_Staffordshire_terrier
# 0
# Persian_cat Boston_bull
# 0
# Persian_cat French_bulldog
# 0
# Persian_cat pug
# 0
# Persian_cat tabby
# 0.21922742621973157
# Persian_cat Persian_cat
# 0
# Persian_cat Siamese_cat
# 0
# Persian_cat Egyptian_cat
# 0
# Persian_cat wood_rabbit
# 0
# Persian_cat hare
# 0
# Persian_cat Angora
# 0.005036433730936096
# Persian_cat hamster
# 0
# Persian_cat marmot
# 0
# Persian_cat beaver
# 0
# Persian_cat guinea_pig
# 0
# Siamese_cat drake
# 0
# Siamese_cat red-breasted_merganser
# 0
# Siamese_cat goose
# 0
# Siamese_cat black_swan
# 0
# Siamese_cat wallaby
# 0
# Siamese_cat American_coot
# 0
# Siamese_cat Chihuahua
# 0.0021040719002485275
# Siamese_cat American_Staffordshire_terrier
# 0
# Siamese_cat Boston_bull
# 0
# Siamese_cat French_bulldog
# 0
# Siamese_cat pug
# 0.04610663070343435
# Siamese_cat tabby
# 0
# Siamese_cat Persian_cat
# 8.409626025240868e-05
# Siamese_cat Siamese_cat
# 0
# Siamese_cat Egyptian_cat
# 0
# Siamese_cat wood_rabbit
# 0
# Siamese_cat hare
# 0
# Siamese_cat Angora
# 0
# Siamese_cat hamster
# 0
# Siamese_cat marmot
# 0
# Siamese_cat beaver
# 0
# Siamese_cat guinea_pig
# 0
# Egyptian_cat drake
# 0
# Egyptian_cat red-breasted_merganser
# 0
# Egyptian_cat goose
# 0
# Egyptian_cat black_swan
# 0
# Egyptian_cat wallaby
# 0
# Egyptian_cat American_coot
# 0
# Egyptian_cat Chihuahua
# 0
# Egyptian_cat American_Staffordshire_terrier
# 0
# Egyptian_cat Boston_bull
# 0
# Egyptian_cat French_bulldog
# 0
# Egyptian_cat pug
# 0
# Egyptian_cat tabby
# 1.5366775165311992
# Egyptian_cat Persian_cat
# 0
# Egyptian_cat Siamese_cat
# 3.43546736303324e-05
# Egyptian_cat Egyptian_cat
# 0
# Egyptian_cat wood_rabbit
# 0
# Egyptian_cat hare
# 0
# Egyptian_cat Angora
# 0
# Egyptian_cat hamster
# 0
# Egyptian_cat marmot
# 0
# Egyptian_cat beaver
# 0
# Egyptian_cat guinea_pig
# 0
# wood_rabbit drake
# 0
# wood_rabbit red-breasted_merganser
# 0
# wood_rabbit goose
# 0
# wood_rabbit black_swan
# 0
# wood_rabbit wallaby
# 0.5690056326820923
# wood_rabbit American_coot
# 0
# wood_rabbit Chihuahua
# 0
# wood_rabbit American_Staffordshire_terrier
# 0
# wood_rabbit Boston_bull
# 0
# wood_rabbit French_bulldog
# 0.0003141867637168616
# wood_rabbit pug
# 0
# wood_rabbit tabby
# 0
# wood_rabbit Persian_cat
# 0
# wood_rabbit Siamese_cat
# 0
# wood_rabbit Egyptian_cat
# 0
# wood_rabbit wood_rabbit
# 0
# wood_rabbit hare
# 1.106748345773667
# wood_rabbit Angora
# 0.02711390690274129
# wood_rabbit hamster
# 0
# wood_rabbit marmot
# 0
# wood_rabbit beaver
# 0
# wood_rabbit guinea_pig
# 0.002020209631155012
# hare drake
# 0
# hare red-breasted_merganser
# 0
# hare goose
# 0
# hare black_swan
# 0
# hare wallaby
# 0.22278292640839936
# hare American_coot
# 0
# hare Chihuahua
# 0
# hare American_Staffordshire_terrier
# 0
# hare Boston_bull
# 0
# hare French_bulldog
# 0.00010429041867610067
# hare pug
# 0
# hare tabby
# 0
# hare Persian_cat
# 0
# hare Siamese_cat
# 0
# hare Egyptian_cat
# 0
# hare wood_rabbit
# 0.5805068514309824
# hare hare
# 0
# hare Angora
# 0.027937755268794717
# hare hamster
# 0
# hare marmot
# 0.018780963495373726
# hare beaver
# 0
# hare guinea_pig
# 9.975732808698012e-07
# Angora drake
# 0
# Angora red-breasted_merganser
# 0
# Angora goose
# 0
# Angora black_swan
# 0
# Angora wallaby
# 0.0002852001634892076
# Angora American_coot
# 0
# Angora Chihuahua
# 0
# Angora American_Staffordshire_terrier
# 0
# Angora Boston_bull
# 0
# Angora French_bulldog
# 0
# Angora pug
# 0
# Angora tabby
# 0
# Angora Persian_cat
# 0.00012074210098944604
# Angora Siamese_cat
# 0
# Angora Egyptian_cat
# 0
# Angora wood_rabbit
# 0.0002962696766672934
# Angora hare
# 0.029496120961539418
# Angora Angora
# 0
# Angora hamster
# 0.002219507936388254
# Angora marmot
# 0
# Angora beaver
# 0
# Angora guinea_pig
# 0.02418958746784483
# hamster drake
# 0
# hamster red-breasted_merganser
# 0
# hamster goose
# 0
# hamster black_swan
# 0
# hamster wallaby
# 0
# hamster American_coot
# 0
# hamster Chihuahua
# 0
# hamster American_Staffordshire_terrier
# 0
# hamster Boston_bull
# 0
# hamster French_bulldog
# 0
# hamster pug
# 0
# hamster tabby
# 0
# hamster Persian_cat
# 0
# hamster Siamese_cat
# 0
# hamster Egyptian_cat
# 0
# hamster wood_rabbit
# 0
# hamster hare
# 0
# hamster Angora
# 0.0006123925568317645
# hamster hamster
# 0
# hamster marmot
# 0
# hamster beaver
# 0
# hamster guinea_pig
# 0.034928497271721426
# marmot drake
# 0
# marmot red-breasted_merganser
# 0
# marmot goose
# 0
# marmot black_swan
# 0
# marmot wallaby
# 0.03973236831370741
# marmot American_coot
# 0
# marmot Chihuahua
# 0
# marmot American_Staffordshire_terrier
# 0
# marmot Boston_bull
# 0
# marmot French_bulldog
# 0
# marmot pug
# 0
# marmot tabby
# 0
# marmot Persian_cat
# 0
# marmot Siamese_cat
# 0
# marmot Egyptian_cat
# 0
# marmot wood_rabbit
# 0
# marmot hare
# 8.066471491474658e-05
# marmot Angora
# 0
# marmot hamster
# 0.00033156032441183925
# marmot marmot
# 0
# marmot beaver
# 0.904610318228606
# marmot guinea_pig
# 0
# beaver drake
# 0
# beaver red-breasted_merganser
# 0
# beaver goose
# 0
# beaver black_swan
# 0
# beaver wallaby
# 0.041787609457969666
# beaver American_coot
# 0
# beaver Chihuahua
# 0
# beaver American_Staffordshire_terrier
# 0
# beaver Boston_bull
# 0
# beaver French_bulldog
# 0
# beaver pug
# 0
# beaver tabby
# 0
# beaver Persian_cat
# 0
# beaver Siamese_cat
# 0
# beaver Egyptian_cat
# 0
# beaver wood_rabbit
# 0
# beaver hare
# 0
# beaver Angora
# 0
# beaver hamster
# 0.012656630471610697
# beaver marmot
# 0.16041730475808436
# beaver beaver
# 0
# beaver guinea_pig
# 3.0349479857250117e-05
# guinea_pig drake
# 0
# guinea_pig red-breasted_merganser
# 0
# guinea_pig goose
# 0
# guinea_pig black_swan
# 0
# guinea_pig wallaby
# 0.024702487513422966
# guinea_pig American_coot
# 0
# guinea_pig Chihuahua
# 0
# guinea_pig American_Staffordshire_terrier
# 0
# guinea_pig Boston_bull
# 0
# guinea_pig French_bulldog
# 0
# guinea_pig pug
# 0
# guinea_pig tabby
# 0
# guinea_pig Persian_cat
# 0
# guinea_pig Siamese_cat
# 0
# guinea_pig Egyptian_cat
# 0
# guinea_pig wood_rabbit
# 7.479866326320916e-07
# guinea_pig hare
# 0
# guinea_pig Angora
# 0.0004606955553754233
# guinea_pig hamster
# 0.06973152101659252
# guinea_pig marmot
# 0
# guinea_pig beaver
# 0
# guinea_pig guinea_pig
# 0
# Components:
# Component 1: {'French_bulldog', 'Egyptian_cat', 'guinea_pig', 'Chihuahua', 'Siamese_cat', 'wallaby', 'hamster', 'wood_rabbit', 'Persian_cat', 'hare', 'Angora', 'tabby', 'marmot', 'American_Staffordshire_terrier', 'Boston_bull', 'pug', 'beaver'}
# Component 2: {'American_coot', 'black_swan', 'red-breasted_merganser', 'goose', 'drake'}
# Components:
# Component 1: {'French_bulldog', 'Egyptian_cat', 'guinea_pig', 'Chihuahua', 'Siamese_cat', 'wallaby', 'hamster', 'wood_rabbit', 'Persian_cat', 'hare', 'Angora', 'tabby', 'marmot', 'American_Staffordshire_terrier', 'Boston_bull', 'pug', 'beaver'}
# Component 2: {'American_coot', 'black_swan', 'red-breasted_merganser', 'goose', 'drake'}
# Components:
# Component 1: {'Egyptian_cat', 'guinea_pig', 'French_bulldog', 'Chihuahua', 'Siamese_cat', 'wallaby', 'hamster', 'wood_rabbit', 'Persian_cat', 'hare', 'Angora', 'tabby', 'marmot', 'American_Staffordshire_terrier', 'Boston_bull', 'pug', 'beaver'}
# Component 2: {'American_coot', 'black_swan', 'red-breasted_merganser', 'goose', 'drake'}
# Components:
# Component 1: {'Egyptian_cat', 'tabby'}
# Component 2: {'French_bulldog', 'Chihuahua', 'American_Staffordshire_terrier', 'Boston_bull', 'pug'}
# Component 3: {'Siamese_cat'}
# Component 4: {'Persian_cat'}
# Component 5: {'wallaby'}
# Component 6: {'hamster', 'guinea_pig'}
# Component 7: {'marmot', 'beaver'}
# Component 8: {'Angora', 'hare', 'wood_rabbit'}
# Component 9: {'American_coot', 'black_swan', 'red-breasted_merganser', 'goose', 'drake'}
# Components:
# Component 1: {'Egyptian_cat', 'tabby'}
# Component 2: {'French_bulldog', 'Chihuahua', 'American_Staffordshire_terrier', 'Boston_bull', 'pug'}
# Component 3: {'Siamese_cat'}
# Component 4: {'Persian_cat'}
# Component 5: {'wallaby'}
# Component 6: {'Angora', 'hare', 'wood_rabbit'}
# Component 7: {'hamster', 'guinea_pig'}
# Component 8: {'marmot', 'beaver'}
# Component 9: {'American_coot', 'black_swan', 'red-breasted_merganser', 'goose', 'drake'}
# Components:
# Component 1: {'Egyptian_cat', 'tabby'}
# Component 2: {'French_bulldog', 'Chihuahua', 'American_Staffordshire_terrier', 'Boston_bull', 'pug'}
# Component 3: {'Siamese_cat'}
# Component 4: {'Persian_cat'}
# Component 5: {'Angora'}
# Component 6: {'wallaby'}
# Component 7: {'hare', 'wood_rabbit'}
# Component 8: {'hamster'}
# Component 9: {'marmot', 'beaver'}
# Component 10: {'guinea_pig'}
# Component 11: {'red-breasted_merganser', 'drake'}
# Component 12: {'American_coot', 'black_swan'}
# Component 13: {'goose'}
# Components:
# Component 1: {'Siamese_cat'}
# Component 2: {'Egyptian_cat', 'tabby'}
# Component 3: {'Persian_cat'}
# Component 4: {'Chihuahua'}
# Component 5: {'French_bulldog', 'American_Staffordshire_terrier', 'Boston_bull', 'pug'}
# Component 6: {'Angora'}
# Component 7: {'wallaby'}
# Component 8: {'hare', 'wood_rabbit'}
# Component 9: {'hamster'}
# Component 10: {'marmot', 'beaver'}
# Component 11: {'guinea_pig'}
# Component 12: {'American_coot'}
# Component 13: {'red-breasted_merganser'}
# Component 14: {'drake'}
# Component 15: {'goose'}
# Component 16: {'black_swan'}
# Components:
# Component 1: {'Siamese_cat'}
# Component 2: {'Egyptian_cat', 'tabby'}
# Component 3: {'Persian_cat'}
# Component 4: {'Chihuahua'}
# Component 5: {'American_Staffordshire_terrier'}
# Component 6: {'French_bulldog', 'Boston_bull', 'pug'}
# Component 7: {'Angora'}
# Component 8: {'wallaby'}
# Component 9: {'hare', 'wood_rabbit'}
# Component 10: {'hamster'}
# Component 11: {'beaver'}
# Component 12: {'guinea_pig'}
# Component 13: {'marmot'}
# Component 14: {'American_coot'}
# Component 15: {'red-breasted_merganser'}
# Component 16: {'drake'}
# Component 17: {'goose'}
# Component 18: {'black_swan'}
# Components:
# Component 1: {'Siamese_cat'}
# Component 2: {'Egyptian_cat', 'tabby'}
# Component 3: {'Persian_cat'}
# Component 4: {'Chihuahua'}
# Component 5: {'American_Staffordshire_terrier'}
# Component 6: {'French_bulldog', 'Boston_bull'}
# Component 7: {'pug'}
# Component 8: {'Angora'}
# Component 9: {'hare'}
# Component 10: {'wood_rabbit'}
# Component 11: {'wallaby'}
# Component 12: {'hamster'}
# Component 13: {'beaver'}
# Component 14: {'guinea_pig'}
# Component 15: {'marmot'}
# Component 16: {'American_coot'}
# Component 17: {'red-breasted_merganser'}
# Component 18: {'drake'}
# Component 19: {'goose'}
# Component 20: {'black_swan'}

# %%
# Initialize distance and predecessor matrices
num_nodes = len(G.nodes)
inf = float('inf')
distance_matrix = [[inf] * num_nodes for _ in range(num_nodes)]
predecessor_matrix = [[None] * num_nodes for _ in range(num_nodes)]

# Set the distance matrix based on the existing edges in the graph
for u, v, data in G.edges(data=True):
    weight = data.get('weight', 0)  # Default weight is 0 if not specified
    u_index = list(G.nodes).index(u)
    v_index = list(G.nodes).index(v)
    distance_matrix[u_index][v_index] = 4 - weight
    predecessor_matrix[u_index][v_index] = u

# Apply Floyd-Warshall algorithm with predecessor tracking
for k in range(num_nodes):
    for i in range(num_nodes):
        for j in range(num_nodes):
            if distance_matrix[i][k] + distance_matrix[k][j] < distance_matrix[i][j]:
                distance_matrix[i][j] = distance_matrix[i][k] + distance_matrix[k][j]
                predecessor_matrix[i][j] = predecessor_matrix[k][j]

# Display shortest paths for each node to all others
print("Shortest Paths:")
for source_index in range(num_nodes):
    source_node = list(G.nodes)[source_index]
    print(f"* From node '{source_node}': * ")
    for target_index in range(num_nodes):
        target_node = list(G.nodes)[target_index]
        if source_node == target_node:
            print(f"To node '{target_node}': {source_node}")
        else:
            path = [target_node]
            predecessor = predecessor_matrix[source_index][target_index]
            while predecessor is not None and predecessor != source_node:
                path.insert(0, predecessor)
                predecessor_index = list(G.nodes).index(predecessor)
                predecessor = predecessor_matrix[source_index][predecessor_index]
            if predecessor == source_node:
                path.insert(0, source_node)
                print(f"To node '{target_node}': {' -> '.join(path)} (Distance: {distance_matrix[source_index][target_index]})")
            else:
                print(f"To node '{target_node}': No path exists.")
# Out:
# Shortest Paths:
# * From node 'Siamese_cat': *
# To node 'Siamese_cat': Siamese_cat
# To node 'tabby': Siamese_cat -> Persian_cat -> tabby (Distance: 7.780688477520016)
# To node 'Persian_cat': Siamese_cat -> Persian_cat (Distance: 3.9999159037397476)
# To node 'Egyptian_cat': Siamese_cat -> Persian_cat -> tabby -> Egyptian_cat (Distance: 10.226540728319378)
# To node 'Chihuahua': Siamese_cat -> Chihuahua (Distance: 3.9978959280997515)
# To node 'American_Staffordshire_terrier': Siamese_cat -> pug -> American_Staffordshire_terrier (Distance: 7.952588112442754)
# To node 'Boston_bull': Siamese_cat -> pug -> Boston_bull (Distance: 7.918869081950106)
# To node 'French_bulldog': Siamese_cat -> pug -> French_bulldog (Distance: 7.389781372608013)
# To node 'pug': Siamese_cat -> pug (Distance: 3.9538933692965657)
# To node 'Angora': Siamese_cat -> Persian_cat -> Angora (Distance: 7.9948794700088115)
# To node 'hare': Siamese_cat -> Persian_cat -> Angora -> hare (Distance: 11.965383349047272)
# To node 'wood_rabbit': Siamese_cat -> Persian_cat -> Angora -> wood_rabbit (Distance: 11.994583200332144)
# To node 'wallaby': Siamese_cat -> Persian_cat -> Angora -> wallaby (Distance: 11.994594269845322)
# To node 'hamster': Siamese_cat -> Persian_cat -> Angora -> hamster (Distance: 11.992659962072423)
# To node 'beaver': Siamese_cat -> Persian_cat -> Angora -> hare -> marmot -> beaver (Distance: 19.041992067323292)
# To node 'guinea_pig': Siamese_cat -> Persian_cat -> Angora -> guinea_pig (Distance: 11.970689882540967)
# To node 'marmot': Siamese_cat -> Persian_cat -> Angora -> hare -> marmot (Distance: 15.946602385551898)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'tabby': *
# To node 'Siamese_cat': tabby -> Egyptian_cat -> Siamese_cat (Distance: 6.445817896125732)
# To node 'tabby': tabby
# To node 'Persian_cat': tabby -> Persian_cat (Distance: 3.9971928876296374)
# To node 'Egyptian_cat': tabby -> Egyptian_cat (Distance: 2.445852250799362)
# To node 'Chihuahua': tabby -> Egyptian_cat -> Siamese_cat -> Chihuahua (Distance: 10.443713824225483)
# To node 'American_Staffordshire_terrier': tabby -> Egyptian_cat -> Siamese_cat -> pug -> American_Staffordshire_terrier (Distance: 14.398406008568486)
# To node 'Boston_bull': tabby -> Egyptian_cat -> Siamese_cat -> pug -> Boston_bull (Distance: 14.364686978075838)
# To node 'French_bulldog': tabby -> Egyptian_cat -> Siamese_cat -> pug -> French_bulldog (Distance: 13.835599268733745)
# To node 'pug': tabby -> Egyptian_cat -> Siamese_cat -> pug (Distance: 10.399711265422297)
# To node 'Angora': tabby -> Persian_cat -> Angora (Distance: 7.992156453898701)
# To node 'hare': tabby -> Persian_cat -> Angora -> hare (Distance: 11.962660332937162)
# To node 'wood_rabbit': tabby -> Persian_cat -> Angora -> wood_rabbit (Distance: 11.991860184222034)
# To node 'wallaby': tabby -> Persian_cat -> Angora -> wallaby (Distance: 11.991871253735212)
# To node 'hamster': tabby -> Persian_cat -> Angora -> hamster (Distance: 11.989936945962313)
# To node 'beaver': tabby -> Persian_cat -> Angora -> hare -> marmot -> beaver (Distance: 19.039269051213182)
# To node 'guinea_pig': tabby -> Persian_cat -> Angora -> guinea_pig (Distance: 11.967966866430856)
# To node 'marmot': tabby -> Persian_cat -> Angora -> hare -> marmot (Distance: 15.943879369441788)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'Persian_cat': *
# To node 'Siamese_cat': Persian_cat -> tabby -> Egyptian_cat -> Siamese_cat (Distance: 10.226590469906)
# To node 'tabby': Persian_cat -> tabby (Distance: 3.7807725737802684)
# To node 'Persian_cat': Persian_cat
# To node 'Egyptian_cat': Persian_cat -> tabby -> Egyptian_cat (Distance: 6.2266248245796305)
# To node 'Chihuahua': Persian_cat -> Angora -> wallaby -> Chihuahua (Distance: 11.982536541405636)
# To node 'American_Staffordshire_terrier': Persian_cat -> Angora -> hare -> French_bulldog -> American_Staffordshire_terrier (Distance: 15.58884245603059)
# To node 'Boston_bull': Persian_cat -> Angora -> hare -> French_bulldog -> Boston_bull (Distance: 13.027972415674242)
# To node 'French_bulldog': Persian_cat -> Angora -> hare -> French_bulldog (Distance: 11.965363154888848)
# To node 'pug': Persian_cat -> tabby -> Egyptian_cat -> Siamese_cat -> pug (Distance: 14.180483839202566)
# To node 'Angora': Persian_cat -> Angora (Distance: 3.994963566269064)
# To node 'hare': Persian_cat -> Angora -> hare (Distance: 7.9654674453075245)
# To node 'wood_rabbit': Persian_cat -> Angora -> wood_rabbit (Distance: 7.994667296592397)
# To node 'wallaby': Persian_cat -> Angora -> wallaby (Distance: 7.994678366105575)
# To node 'hamster': Persian_cat -> Angora -> hamster (Distance: 7.992744058332676)
# To node 'beaver': Persian_cat -> Angora -> hare -> marmot -> beaver (Distance: 15.042076163583545)
# To node 'guinea_pig': Persian_cat -> Angora -> guinea_pig (Distance: 7.970773978801219)
# To node 'marmot': Persian_cat -> Angora -> hare -> marmot (Distance: 11.94668648181215)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'Egyptian_cat': *
# To node 'Siamese_cat': Egyptian_cat -> Siamese_cat (Distance: 3.9999656453263697)
# To node 'tabby': Egyptian_cat -> tabby (Distance: 2.463322483468801)
# To node 'Persian_cat': Egyptian_cat -> tabby -> Persian_cat (Distance: 6.460515371098438)
# To node 'Egyptian_cat': Egyptian_cat
# To node 'Chihuahua': Egyptian_cat -> Siamese_cat -> Chihuahua (Distance: 7.997861573426121)
# To node 'American_Staffordshire_terrier': Egyptian_cat -> Siamese_cat -> pug -> American_Staffordshire_terrier (Distance: 11.952553757769124)
# To node 'Boston_bull': Egyptian_cat -> Siamese_cat -> pug -> Boston_bull (Distance: 11.918834727276476)
# To node 'French_bulldog': Egyptian_cat -> Siamese_cat -> pug -> French_bulldog (Distance: 11.389747017934383)
# To node 'pug': Egyptian_cat -> Siamese_cat -> pug (Distance: 7.953859014622935)
# To node 'Angora': Egyptian_cat -> tabby -> Persian_cat -> Angora (Distance: 10.455478937367502)
# To node 'hare': Egyptian_cat -> tabby -> Persian_cat -> Angora -> hare (Distance: 14.425982816405963)
# To node 'wood_rabbit': Egyptian_cat -> tabby -> Persian_cat -> Angora -> wood_rabbit (Distance: 14.455182667690835)
# To node 'wallaby': Egyptian_cat -> tabby -> Persian_cat -> Angora -> wallaby (Distance:

# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'Boston_bull': *
# To node 'Siamese_cat': Boston_bull -> pug -> Siamese_cat (Distance: 7.557823812889637)
# To node 'tabby': Boston_bull -> pug -> tabby (Distance: 7.495686173077502)
# To node 'Persian_cat': Boston_bull -> pug -> tabby -> Persian_cat (Distance: 11.49287906070714)
# To node 'Egyptian_cat': Boston_bull -> pug -> tabby -> Egyptian_cat (Distance: 9.941538423876864)
# To node 'Chihuahua': Boston_bull -> French_bulldog -> Chihuahua (Distance: 3.3341303863562644)
# To node 'American_Staffordshire_terrier': Boston_bull -> American_Staffordshire_terrier (Distance: 3.4404462086531566)
# To node 'Boston_bull': Boston_bull
# To node 'French_bulldog': Boston_bull -> French_bulldog (Distance: 0.3053341343329521)
# To node 'pug': Boston_bull -> pug (Distance: 3.5633276548346657)
# To node 'Angora': Boston_bull -> pug -> tabby -> Persian_cat -> Angora (Distance: 15.487842626976203)
# To node 'hare': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> hare (Distance: 19.458346506014664)
# To node 'wood_rabbit': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> wood_rabbit (Distance: 19.487546357299536)
# To node 'wallaby': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> wallaby (Distance: 19.487557426812714)
# To node 'hamster': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> hamster (Distance: 19.485623119039815)
# To node 'beaver': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> hare -> marmot -> beaver (Distance: 26.534955224290684)
# To node 'guinea_pig': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> guinea_pig (Distance: 19.46365303950836)
# To node 'marmot': Boston_bull -> pug -> tabby -> Persian_cat -> Angora -> hare -> marmot (Distance: 23.43956554251929)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'French_bulldog': *
# To node 'Siamese_cat': French_bulldog -> pug -> Siamese_cat (Distance: 7.571482215614651)
# To node 'tabby': French_bulldog -> pug -> tabby (Distance: 7.5093445758025155)
# To node 'Persian_cat': French_bulldog -> pug -> tabby -> Persian_cat (Distance: 11.506537463432153)
# To node 'Egyptian_cat': French_bulldog -> pug -> tabby -> Egyptian_cat (Distance: 9.955196826601878)
# To node 'Chihuahua': French_bulldog -> Chihuahua (Distance: 3.0287962520233123)
# To node 'American_Staffordshire_terrier': French_bulldog -> American_Staffordshire_terrier (Distance: 3.6234793011417423)
# To node 'Boston_bull': French_bulldog -> Boston_bull (Distance: 1.0626092607853934)
# To node 'French_bulldog': French_bulldog
# To node 'pug': French_bulldog -> pug (Distance: 3.5769860575596795)
# To node 'Angora': French_bulldog -> pug -> tabby -> Persian_cat -> Angora (Distance: 15.501501029701217)
# To node 'hare': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> hare (Distance: 19.472004908739677)
# To node 'wood_rabbit': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> wood_rabbit (Distance: 19.50120476002455)
# To node 'wallaby': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> wallaby (Distance: 19.501215829537728)
# To node 'hamster': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> hamster (Distance: 19.49928152176483)
# To node 'beaver': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> hare -> marmot -> beaver (Distance: 26.548613627015698)
# To node 'guinea_pig': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> guinea_pig (Distance: 19.477311442233372)
# To node 'marmot': French_bulldog -> pug -> tabby -> Persian_cat -> Angora -> hare -> marmot (Distance: 23.453223945244304)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'pug': *
# To node 'Siamese_cat': pug -> Siamese_cat (Distance: 3.9944961580549716)
# To node 'tabby': pug -> tabby (Distance: 3.932358518242836)
# To node 'Persian_cat': pug -> tabby -> Persian_cat (Distance: 7.929551405872473)
# To node 'Egyptian_cat': pug -> tabby -> Egyptian_cat (Distance: 6.378210769042198)
# To node 'Chihuahua': pug -> French_bulldog -> Chihuahua (Distance: 6.46468425533476)
# To node 'American_Staffordshire_terrier': pug -> American_Staffordshire_terrier (Distance: 3.9986947431461886)
# To node 'Boston_bull': pug -> Boston_bull (Distance: 3.9649757126535405)
# To node 'French_bulldog': pug -> French_bulldog (Distance: 3.4358880033114474)
# To node 'pug': pug
# To node 'Angora': pug -> tabby -> Persian_cat -> Angora (Distance: 11.924514972141537)
# To node 'hare': pug -> tabby -> Persian_cat -> Angora -> hare (Distance: 15.895018851179998)
# To node 'wood_rabbit': pug -> tabby -> Persian_cat -> Angora -> wood_rabbit (Distance: 15.92421870246487)
# To node 'wallaby': pug -> tabby -> Persian_cat -> Angora -> wallaby (Distance: 15.924229771978048)
# To node 'hamster': pug -> tabby -> Persian_cat -> Angora -> hamster (Distance: 15.922295464205149)
# To node 'beaver': pug -> tabby -> Persian_cat -> Angora -> hare -> marmot -> beaver (Distance: 22.971627569456018)
# To node 'guinea_pig': pug -> tabby -> Persian_cat -> Angora -> guinea_pig (Distance: 15.900325384673692)
# To node 'marmot': pug -> tabby -> Persian_cat -> Angora -> hare -> marmot (Distance: 19.876237887684624)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'Angora': *
# To node 'Siamese_cat': Angora -> Persian_cat -> tabby -> Egyptian_cat -> Siamese_cat (Distance: 14.22646972780501)
# To node 'tabby': Angora -> Persian_cat -> tabby (Distance: 7.780651831679279)
# To node 'Persian_cat': Angora -> Persian_cat (Distance: 3.9998792578990106)
# To node 'Egyptian_cat': Angora -> Persian_cat -> tabby -> Egyptian_cat (Distance: 10.226504082478641)
# To node 'Chihuahua': Angora -> wallaby -> Chihuahua (Distance: 7.9875729751365725)
# To node 'American_Staffordshire_terrier': Angora -> hare -> French_bulldog -> American_Staffordshire_terrier (Distance: 11.593878889761527)
# To node 'Boston_bull': Angora -> hare -> French_bulldog -> Boston_bull (Distance: 9.033008849405178)
# To node 'French_bulldog': Angora -> hare -> French_bulldog (Distance: 7.9703995886197845)
# To node 'pug': Angora -> hare -> French_bulldog -> pug (Distance: 11.547385646179464)
# To node 'Angora': Angora
# To node 'hare': Angora -> hare (Distance: 3.9705038790384606)
# To node 'wood_rabbit': Angora -> wood_rabbit (Distance: 3.9997037303233327)
# To node 'wallaby': Angora -> wallaby (Distance: 3.999714799836511)
# To node 'hamster': Angora -> hamster (Distance: 3.9977804920636117)
# To node 'beaver': Angora -> hare -> marmot -> beaver (Distance: 11.04711259731448)
# To node 'guinea_pig': Angora -> guinea_pig (Distance: 3.975810412532155)
# To node 'marmot': Angora -> hare -> marmot (Distance: 7.951722915543087)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'hare': *
# To node 'Siamese_cat': hare -> French_bulldog -> pug -> Siamese_cat (Distance: 11.571377925195975)
# To node 'tabby': hare -> French_bulldog -> pug -> tabby (Distance: 11.50924028538384)
# To node 'Persian_cat': hare -> Angora -> Persian_cat (Distance: 7.971941502630216)
# To node 'Egyptian_cat': hare -> French_bulldog -> pug -> tabby -> Egyptian_cat (Distance: 13.955092536183201)
# To node 'Chihuahua': hare -> French_bulldog -> Chihuahua (Distance: 7.028691961604636)
# To node 'American_Staffordshire_terrier': hare -> French_bulldog -> American_Staffordshire_terrier (Distance: 7.623375010723066)
# To node 'Boston_bull': hare -> French_bulldog -> Boston_bull (Distance: 5.062504970366717)
# To node 'French_bulldog': hare -> French_bulldog (Distance: 3.999895709581324)
# To node 'pug': hare -> French_bulldog -> pug (Distance: 7.576881767141003)
# To node 'Angora': hare -> Angora (Distance: 3.9720622447312053)
# To node 'hare': hare
# To node 'wood_rabbit': hare -> wood_rabbit (Distance: 3.4194931485690176)
# To node 'wallaby': hare -> wallaby (Distance: 3.7772170735916006)
# To node 'hamster': hare -> guinea_pig -> hamster (Distance: 7.930267481410127)
# To node 'beaver': hare -> marmot -> beaver (Distance: 7.07660871827602)
# To node 'guinea_pig': hare -> guinea_pig (Distance: 3.999999002426719)
# To node 'marmot': hare -> marmot (Distance: 3.9812190365046263)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'wood_rabbit': *
# To node 'Siamese_cat': wood_rabbit -> French_bulldog -> pug -> Siamese_cat (Distance: 11.571168028850934)
# To node 'tabby': wood_rabbit -> French_bulldog -> pug -> tabby (Distance: 11.509030389038799)
# To node 'Persian_cat': wood_rabbit -> Angora -> Persian_cat (Distance: 7.972765350996269)
# To node 'Egyptian_cat': wood_rabbit -> French_bulldog -> pug -> tabby -> Egyptian_cat (Distance: 13.95488263983816)
# To node 'Chihuahua': wood_rabbit -> French_bulldog -> Chihuahua (Distance: 7.028482065259595)
# To node 'American_Staffordshire_terrier': wood_rabbit -> French_bulldog -> American_Staffordshire_terrier (Distance: 7.6231651143780255)
# To node 'Boston_bull': wood_rabbit -> French_bulldog -> Boston_bull (Distance: 5.0622950740216766)
# To node 'French_bulldog': wood_rabbit -> French_bulldog (Distance: 3.999685813236283)
# To node 'pug': wood_rabbit -> French_bulldog -> pug (Distance: 7.576671870795963)
# To node 'Angora': wood_rabbit -> Angora (Distance: 3.9728860930972587)
# To node 'hare': wood_rabbit -> hare (Distance: 2.893251654226333)
# To node 'wood_rabbit': wood_rabbit
# To node 'wallaby': wood_rabbit -> wallaby (Distance: 3.4309943673179077)
# To node 'hamster': wood_rabbit -> guinea_pig -> hamster (Distance: 7.9282482693522525)
# To node 'beaver': wood_rabbit -> hare -> marmot -> beaver (Distance: 9.969860372502353)
# To node 'guinea_pig': wood_rabbit -> guinea_pig (Distance: 3.997979790368845)
# To node 'marmot': wood_rabbit -> hare -> marmot (Distance: 6.874470690730959)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'wallaby': *
# To node 'Siamese_cat': wallaby -> Chihuahua -> pug -> Siamese_cat (Distance: 11.982144763045653)
# To node 'tabby': wallaby -> Angora -> Persian_cat -> tabby (Distance: 11.780392752378248)
# To node 'Persian_cat': wallaby -> Angora -> Persian_cat (Distance: 7.999620178597979)
# To node 'Egyptian_cat': wallaby -> Angora -> Persian_cat -> tabby -> Egyptian_cat (Distance: 14.22624500317761)
# To node 'Chihuahua': wallaby -> Chihuahua (Distance: 3.9878581753000617)
# To node 'American_Staffordshire_terrier': wallaby -> Chihuahua -> American_Staffordshire_terrier (Distance: 7.98636682680808)
# To node 'Boston_bull': wallaby -> Chihuahua -> Boston_bull (Distance: 7.919008070811287)
# To node 'French_bulldog': wallaby -> Chihuahua -> French_bulldog (Distance: 7.933634578345163)
# To node 'pug': wallaby -> Chihuahua -> pug (Distance: 7.987648604990682)
# To node 'Angora': wallaby -> Angora (Distance: 3.9997409206989687)
# To node 'hare': wallaby -> hare (Distance: 3.999661736273083)
# To node 'wood_rabbit': wallaby -> wood_rabbit (Distance: 3.991962973174509)
# To node 'wallaby': wallaby
# To node 'hamster': wallaby -> marmot -> hamster (Distance: 7.988726410840172)
# To node 'beaver': wallaby -> marmot -> beaver (Distance: 7.084447652935978)
# To node 'guinea_pig': wallaby -> Angora -> guinea_pig (Distance: 7.975551333231124)
# To node 'marmot': wallaby -> marmot (Distance: 3.989057971164584)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'hamster': *
# To node 'Siamese_cat': hamster -> Angora -> Persian_cat -> tabby -> Egyptian_cat -> Siamese_cat (Distance: 18.22585733524818)
# To node 'tabby': hamster -> Angora -> Persian_cat -> tabby (Distance: 11.780039439122447)
# To node 'Persian_cat': hamster -> Angora -> Persian_cat (Distance: 7.999266865342179)
# To node 'Egyptian_cat': hamster -> Angora -> Persian_cat -> tabby -> Egyptian_cat (Distance: 14.22589168992181)
# To node 'Chihuahua': hamster -> guinea_pig -> wallaby -> Chihuahua (Distance: 11.928227190514917)
# To node 'American_Staffordshire_terrier': hamster -> guinea_pig -> wood_rabbit -> French_bulldog -> American_Staffordshire_terrier (Distance: 15.588235869119671)
# To node 'Boston_bull': hamster -> guinea_pig -> wood_rabbit -> French_bulldog -> Boston_bull (Distance: 13.027365828763322)
# To node 'French_bulldog': hamster -> guinea_pig -> wood_rabbit -> French_bulldog (Distance: 11.964756567977929)
# To node 'pug': hamster -> guinea_pig -> wood_rabbit -> French_bulldog -> pug (Distance: 15.541742625537609)
# To node 'Angora': hamster -> Angora (Distance: 3.9993876074431682)
# To node 'hare': hamster -> Angora -> hare (Distance: 7.969891486481629)
# To node 'wood_rabbit': hamster -> guinea_pig -> wood_rabbit (Distance: 7.965070754741646)
# To node 'wallaby': hamster -> guinea_pig -> wallaby (Distance: 7.940369015214856)
# To node 'hamster': hamster
# To node 'beaver': hamster -> guinea_pig -> wallaby -> marmot -> beaver (Distance: 15.024816668150834)
# To node 'guinea_pig': hamster -> guinea_pig (Distance: 3.9650715027282786)
# To node 'marmot': hamster -> guinea_pig -> wallaby -> marmot (Distance: 11.92942698637944)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'beaver': *
# To node 'Siamese_cat': beaver -> wallaby -> Chihuahua -> pug -> Siamese_cat (Distance: 15.940357153587684)
# To node 'tabby': beaver -> wallaby -> Angora -> Persian_cat -> tabby (Distance: 15.738605142920278)
# To node 'Persian_cat': beaver -> wallaby -> Angora -> Persian_cat (Distance: 11.95783256914001)
# To node 'Egyptian_cat': beaver -> wallaby -> Angora -> Persian_cat -> tabby -> Egyptian_cat (Distance: 18.18445739371964)
# To node 'Chihuahua': beaver -> wallaby -> Chihuahua (Distance: 7.946070565842092)
# To node 'American_Staffordshire_terrier': beaver -> wallaby -> Chihuahua -> American_Staffordshire_terrier (Distance: 11.94457921735011)
# To node 'Boston_bull': beaver -> wallaby -> Chihuahua -> Boston_bull (Distance: 11.877220461353318)
# To node 'French_bulldog': beaver -> marmot -> hare -> French_bulldog (Distance: 11.839397740108325)
# To node 'pug': beaver -> wallaby -> Chihuahua -> pug (Distance: 11.945860995532712)
# To node 'Angora': beaver -> wallaby -> Angora (Distance: 7.957953311240999)
# To node 'hare': beaver -> marmot -> hare (Distance: 7.839502030527001)
# To node 'wood_rabbit': beaver -> wallaby -> wood_rabbit (Distance: 7.950175363716539)
# To node 'wallaby': beaver -> wallaby (Distance: 3.9582123905420303)
# To node 'hamster': beaver -> hamster (Distance: 3.9873433695283893)
# To node 'beaver': beaver
# To node 'guinea_pig': beaver -> guinea_pig (Distance: 3.9999696505201427)
# To node 'marmot': beaver -> marmot (Distance: 3.8395826952419156)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'guinea_pig': *
# To node 'Siamese_cat': guinea_pig -> wood_rabbit -> French_bulldog -> pug -> Siamese_cat (Distance: 15.571167280864302)
# To node 'tabby': guinea_pig -> Angora -> Persian_cat -> tabby (Distance: 11.780191136123904)
# To node 'Persian_cat': guinea_pig -> Angora -> Persian_cat (Distance: 7.999418562343635)
# To node 'Egyptian_cat': guinea_pig -> Angora -> Persian_cat -> tabby -> Egyptian_cat (Distance: 14.226043386923266)
# To node 'Chihuahua': guinea_pig -> wallaby -> Chihuahua (Distance: 7.963155687786639)
# To node 'American_Staffordshire_terrier': guinea_pig -> wood_rabbit -> French_bulldog -> American_Staffordshire_terrier (Distance: 11.623164366391393)
# To node 'Boston_bull': guinea_pig -> wood_rabbit -> French_bulldog -> Boston_bull (Distance: 9.062294326035044)
# To node 'French_bulldog': guinea_pig -> wood_rabbit -> French_bulldog (Distance: 7.9996850652496505)
# To node 'pug': guinea_pig -> wood_rabbit -> French_bulldog -> pug (Distance: 11.57667112280933)
# To node 'Angora': guinea_pig -> Angora (Distance: 3.9995393044446246)
# To node 'hare': guinea_pig -> wood_rabbit -> hare (Distance: 6.8932509062397)
# To node 'wood_rabbit': guinea_pig -> wood_rabbit (Distance: 3.9999992520133674)
# To node 'wallaby': guinea_pig -> wallaby (Distance: 3.975297512486577)
# To node 'hamster': guinea_pig -> hamster (Distance: 3.9302684789834075)
# To node 'beaver': guinea_pig -> wallaby -> marmot -> beaver (Distance: 11.059745165422555)
# To node 'guinea_pig': guinea_pig
# To node 'marmot': guinea_pig -> wallaby -> marmot (Distance: 7.964355483651161)
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'marmot': *
# To node 'Siamese_cat': marmot -> hare -> French_bulldog -> pug -> Siamese_cat (Distance: 15.57129726048106)
# To node 'tabby': marmot -> hare -> French_bulldog -> pug -> tabby (Distance: 15.509159620668925)
# To node 'Persian_cat': marmot -> wallaby -> Angora -> Persian_cat (Distance: 11.959887810284272)
# To node 'Egyptian_cat': marmot -> hare -> French_bulldog -> pug -> tabby -> Egyptian_cat (Distance: 17.955011871468287)
# To node 'Chihuahua': marmot -> wallaby -> Chihuahua (Distance: 7.948125806986354)
# To node 'American_Staffordshire_terrier': marmot -> hare -> French_bulldog -> American_Staffordshire_terrier (Distance: 11.623294346008151)
# To node 'Boston_bull': marmot -> hare -> French_bulldog -> Boston_bull (Distance: 9.062424305651803)
# To node 'French_bulldog': marmot -> hare -> French_bulldog (Distance: 7.999815044866409)
# To node 'pug': marmot -> hare -> French_bulldog -> pug (Distance: 11.576801102426089)
# To node 'Angora': marmot -> wallaby -> Angora (Distance: 7.960008552385261)
# To node 'hare': marmot -> hare (Distance: 3.9999193352850853)
# To node 'wood_rabbit': marmot -> hare -> wood_rabbit (Distance: 7.419412483854103)
# To node 'wallaby': marmot -> wallaby (Distance: 3.9602676316862926)
# To node 'hamster': marmot -> hamster (Distance: 3.999668439675588)
# To node 'beaver': marmot -> beaver (Distance: 3.095389681771394)
# To node 'guinea_pig': marmot -> beaver -> guinea_pig (Distance: 7.095359332291537)
# To node 'marmot': marmot
# To node 'American_coot': No path exists.
# To node 'drake': No path exists.
# To node 'goose': No path exists.
# To node 'black_swan': No path exists.
# To node 'red-breasted_merganser': No path exists.
# * From node 'American_coot': *
# To node 'Siamese_cat': American_coot -> black_swan -> Chihuahua -> pug -> Siamese_cat (Distance: 15.839711419334058)
# To node 'tabby': American_coot -> black_swan -> Chihuahua -> pug -> tabby (Distance: 15.777573779521923)
# To node 'Persian_cat': American_coot -> black_swan -> wood_rabbit -> Angora -> Persian_cat (Distance: 15.87014239592471)
# To node 'Egyptian_cat': American_coot -> black_swan -> Chihuahua -> pug -> tabby -> Egyptian_cat (Distance: 18.223426030321285)
# To node 'Chihuahua': American_coot -> black_swan -> Chihuahua (Distance: 7.845424831588467)
# To node 'American_Staffordshire_terrier': American_coot -> black_swan -> Chihuahua -> American_Staffordshire_terrier (Distance: 11.843933483096485)
# To node 'Boston_bull': American_coot -> black_swan -> Chihuahua -> Boston_bull (Distance: 11.776574727099693)
# To node 'French_bulldog': American_coot -> black_swan -> Chihuahua -> French_bulldog (Distance: 11.791201234633569)
# To node 'pug': American_coot -> black_swan -> Chihuahua -> pug (Distance: 11.845215261279087)
# To node 'Angora': American_coot -> black_swan -> wood_rabbit -> Angora (Distance: 11.870263138025699)
# To node 'hare': American_coot -> black_swan -> wood_rabbit -> hare (Distance: 10.790628699154773)
# To node 'wood_rabbit': American_coot -> black_swan -> wood_rabbit (Distance: 7.89737704492844)
# To node 'wallaby': American_coot -> black_swan -> wood_rabbit -> wallaby (Distance: 11.328371412246348)
# To node 'hamster': American_coot -> black_swan -> wood_rabbit -> guinea_pig -> hamster (Distance: 15.825625314280693)
# To node 'beaver': American_coot -> black_swan -> wood_rabbit -> hare -> marmot -> beaver (Distance: 17.867237417430793)
# To node 'guinea_pig': American_coot -> black_swan -> wood_rabbit -> guinea_pig (Distance: 11.895356835297285)
# To node 'marmot': American_coot -> black_swan -> wood_rabbit -> hare -> marmot (Distance: 14.7718477356594)
# To node 'American_coot': American_coot
# To node 'drake': American_coot -> drake (Distance: 3.992125869643928)
# To node 'goose': American_coot -> goose (Distance: 3.997247525410785)
# To node 'black_swan': American_coot -> black_swan (Distance: 3.8978718972994884)
# To node 'red-breasted_merganser': American_coot -> red-breasted_merganser (Distance: 3.9143085394753143)
# * From node 'drake': *
# To node 'Siamese_cat': drake -> black_swan -> Chihuahua -> pug -> Siamese_cat (Distance: 15.930338161313557)
# To node 'tabby': drake -> black_swan -> Chihuahua -> pug -> tabby (Distance: 15.868200521501421)
# To node 'Persian_cat': drake -> black_swan -> wood_rabbit -> Angora -> Persian_cat (Distance: 15.960769137904208)
# To node 'Egyptian_cat': drake -> black_swan -> Chihuahua -> pug -> tabby -> Egyptian_cat (Distance:
# To node 'beaver': goose -> black_swan -> wood_rabbit -> hare -> marmot -> beaver (Distance: 17.93849428157182)
# To node 'guinea_pig': goose -> black_swan -> wood_rabbit -> guinea_pig (Distance: 11.966613699438312)
# To node 'marmot': goose -> black_swan -> wood_rabbit -> hare -> marmot (Distance: 14.843104599800427)
# To node 'American_coot': goose -> American_coot (Distance: 3.999944508645058)
# To node 'drake': goose -> drake (Distance: 3.783924422259588)
# To node 'goose': goose
# To node 'black_swan': goose -> black_swan (Distance: 3.9691287614405155)
# To node 'red-breasted_merganser': goose -> red-breasted_merganser (Distance: 3.89748627818517)
# * From node 'black_swan': *
# To node 'Siamese_cat': black_swan -> Chihuahua -> pug -> Siamese_cat (Distance: 11.94183952203457)
# To node 'tabby': black_swan -> Chihuahua -> pug -> tabby (Distance: 11.879701882222435)
# To node 'Persian_cat': black_swan -> wood_rabbit -> Angora -> Persian_cat (Distance: 11.972270498625221)
# To node 'Egyptian_cat': black_swan -> Chihuahua -> pug -> tabby -> Egyptian_cat (Distance: 14.325554133021797)
# To node 'Chihuahua': black_swan -> Chihuahua (Distance: 3.9475529342889786)
# To node 'American_Staffordshire_terrier': black_swan -> Chihuahua -> American_Staffordshire_terrier (Distance: 7.946061585796997)
# To node 'Boston_bull': black_swan -> Chihuahua -> Boston_bull (Distance: 7.878702829800204)
# To node 'French_bulldog': black_swan -> Chihuahua -> French_bulldog (Distance: 7.89332933733408)
# To node 'pug': black_swan -> Chihuahua -> pug (Distance: 7.9473433639795985)
# To node 'Angora': black_swan -> wood_rabbit -> Angora (Distance: 7.9723912407262105)
# To node 'hare': black_swan -> wood_rabbit -> hare (Distance: 6.892756801855285)
# To node 'wood_rabbit': black_swan -> wood_rabbit (Distance: 3.999505147628952)
# To node 'wallaby': black_swan -> wood_rabbit -> wallaby (Distance: 7.43049951494686)
# To node 'hamster': black_swan -> wood_rabbit -> guinea_pig -> hamster (Distance: 11.927753416981204)
# To node 'beaver': black_swan -> wood_rabbit -> hare -> marmot -> beaver (Distance: 13.969365520131305)
# To node 'guinea_pig': black_swan -> wood_rabbit -> guinea_pig (Distance: 7.997484937997797)
# To node 'marmot': black_swan -> wood_rabbit -> hare -> marmot (Distance: 10.873975838359911)
# To node 'American_coot': black_swan -> American_coot (Distance: 3.536601354254344)
# To node 'drake': black_swan -> drake (Distance: 3.9999958699833087)
# To node 'goose': black_swan -> goose (Distance: 3.9734270958870184)
# To node 'black_swan': black_swan
# To node 'red-breasted_merganser': black_swan -> drake -> red-breasted_merganser (Distance: 7.387236291264003)
# * From node 'red-breasted_merganser': *
# To node 'Siamese_cat': red-breasted_merganser -> black_swan -> Chihuahua -> pug -> Siamese_cat (Distance: 15.941758758384822)
# To node 'tabby': red-breasted_merganser -> black_swan -> Chihuahua -> pug -> tabby (Distance: 15.879621118572686)
# To node 'Persian_cat': red-breasted_merganser -> black_swan -> wood_rabbit -> Angora -> Persian_cat (Distance: 15.972189734975473)
# To node 'Egyptian_cat': red-breasted_merganser -> black_swan -> Chihuahua -> pug -> tabby -> Egyptian_cat (Distance: 18.325473369372048)
# To node 'Chihuahua': red-breasted_merganser -> black_swan -> Chihuahua (Distance: 7.94747217063923)
# To node 'American_Staffordshire_terrier': red-breasted_merganser -> black_swan -> Chihuahua -> American_Staffordshire_terrier (Distance: 11.945980822147249)
# To node 'Boston_bull': red-breasted_merganser -> black_swan -> Chihuahua -> Boston_bull (Distance: 11.878622066150456)
# To node 'French_bulldog': red-breasted_merganser -> black_swan -> Chihuahua -> French_bulldog (Distance: 11.893248573684332)
# To node 'pug': red-breasted_merganser -> black_swan -> Chihuahua -> pug (Distance: 11.94726260032985)
# To node 'Angora': red-breasted_merganser -> black_swan -> wood_rabbit -> Angora (Distance: 11.972310477076462)
# To node 'hare': red-breasted_merganser -> black_swan -> wood_rabbit -> hare (Distance: 10.892676038205536)
# To node 'wood_rabbit': red-breasted_merganser -> black_swan -> wood_rabbit (Distance: 7.999424383979203)
# To node 'wallaby': red-breasted_merganser -> black_swan -> wood_rabbit -> wallaby (Distance: 11.430418751297111)
# To node 'hamster': red-breasted_merganser -> black_swan -> wood_rabbit -> guinea_pig -> hamster (Distance: 15.927672653331456)
# To node 'beaver': red-breasted_merganser -> black_swan -> wood_rabbit -> hare -> marmot -> beaver (Distance: 17.969284756481557)
# To node 'guinea_pig': red-breasted_merganser -> black_swan -> wood_rabbit -> guinea_pig (Distance: 11.997404174348048)
# To node 'marmot': red-breasted_merganser -> black_swan -> wood_rabbit -> hare -> marmot (Distance: 14.873895074710163)
# To node 'American_coot': red-breasted_merganser -> American_coot (Distance: 3.999699388659792)
# To node 'drake': red-breasted_merganser -> drake (Distance: 3.927424217257169)
# To node 'goose': red-breasted_merganser -> goose (Distance: 3.999924399824522)
# To node 'black_swan': red-breasted_merganser -> black_swan (Distance: 3.9999192363502516)
# To node 'red-breasted_merganser': red-breasted_merganser

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)
    dendrogram(linkage_matrix, **kwargs)

# Your code for processing and clustering the data
# Extract edge weights as features for clustering
edge_weights = 4 - np.array([d['weight'] for u, v, d in G.edges(data=True)])

# Perform Agglomerative Clustering
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)
clustering = model.fit(edge_weights.reshape(-1, 1))

plt.figure(figsize=(10, 6))
plt.title('Hierarchical Clustering Dendrogram')
plot_dendrogram(clustering, truncate_mode="level")
plt.xlabel('Nodes')
plt.ylabel('Distance')
plt.show()

from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, node_labels, **kwargs):
    # Create linkage matrix and then plot the dendrogram
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    # Plot the corresponding dendrogram
    linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)
    dendrogram(linkage_matrix, labels=node_labels, **kwargs)

# Extract node names from the graph G and encode them into numeric identifiers
node_labels = list(G.nodes())
label_to_numeric = {label: i for i, label in enumerate(node_labels)}
numeric_labels = [label_to_numeric[label] for label in node_labels]

# Setting distance_threshold=0 ensures we compute the full tree
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)
clustering = model.fit(np.array(numeric_labels).reshape(-1, 1))

plt.figure(figsize=(10, 6))
plt.title('Hierarchical Clustering Dendrogram')
plot_dendrogram(clustering, node_labels=node_labels, truncate_mode="level")
plt.xlabel('Nodes')
plt.ylabel('Distance')
plt.show()
